# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import log_loss, accuracy_score

# %%
df = pd.read_csv('../Cases/Wisconsin/BreastCancer.csv')
df.head()
# Out:
#      Code  Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# 0   61634      5             4              3        1       2      2
# 1   63375      9             1              2        6       4     10
# 2   76389     10             4              7        2       2      8
# 3   95719      6            10             10       10       8     10
# 4  128059      1             1              1        1       2      5
#
#    BChromatin  NoemN  Mitoses      Class
# 0           2      3        1     Benign
# 1           7      7        2  Malignant
# 2           6      1        1  Malignant
# 3           7     10        7  Malignant
# 4           5      1        1     Benign

# %%
X = df.iloc[:, 1:-1]
y = df['Class']

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
svm = SVC(probability=True, random_state=42)
lr = LogisticRegression()
nb = GaussianNB()

voting = VotingClassifier(estimators=[('SVM', svm),
                                     ('LR', lr),
                                     ('NB', nb)],
                          voting='soft')
voting.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('SVM', SVC(probability=True, random_state=42)),
#                              ('LR', LogisticRegression()),
#                              ('NB', GaussianNB())],
#                  voting='soft')

# %%
y_pred_prob = voting.predict_proba(X_test)[:, 1]
log_loss(y_test, y_pred_prob)
# Out:
# 0.08018728882045023

# %%
y_pred = voting.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9714285714285714

# %%
voting.get_params()
# Out:
# {'estimators': [('SVM', SVC(probability=True, random_state=42)),
#   ('LR', LogisticRegression()),
#   ('NB', GaussianNB())],
#  'flatten_transform': True,
#  'n_jobs': None,
#  'verbose': False,
#  'voting': 'soft',
#  'weights': None,
#  'SVM': SVC(probability=True, random_state=42),
#  'LR': LogisticRegression(),
#  'NB': GaussianNB(),
#  'SVM__C': 1.0,
#  'SVM__break_ties': False,
#  'SVM__cache_size': 200,
#  'SVM__class_weight': None,
#  'SVM__coef0': 0.0,
#  'SVM__decision_function_shape': 'ovr',
#  'SVM__degree': 3,
#  'SVM__gamma': 'scale',
#  'SVM__kernel': 'rbf',
#  'SVM__max_iter': -1,
#  'SVM__probability': True,
#  'SVM__random_state': 42,
#  'SVM__shrinking': True,
#  'SVM__tol': 0.001,
#  'SVM__verbose': False,
#  'LR__C': 1.0,
#  'LR__class_weight': None,
#  'LR__dual': False,
#  'LR__fit_intercept': True,
#  'LR__intercept_scaling': 1,
#  'LR__l1_ratio': None,
#  'LR__max_iter': 100,
#  'LR__multi_class': 'auto',
#  'LR__n_jobs': None,
#  'LR__penalty': 'l2',
#  'LR__random_state': None,
#  'LR__solver': 'lbfgs',
#  'LR__tol': 0.0001,
#  'LR__verbose': 0,
#  'LR__warm_start': False,
#  'NB__priors': None,
#  'NB__var_smoothing': 1e-09}

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
params = {'SVM__gamma': ['scale', 'auto'],
          'SVM__C': np.linspace(0.001, 5, 10),
          'LR__penalty': ['l1', 'l2', 'elastic', None],
          'NB__var_smoothing': np.linspace(0.0001, 0.999, 10)}
gcv = GridSearchCV(voting, param_grid=params, verbose=3, cv=kfold, scoring='neg_log_loss')
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 800 candidates, totalling 4000 fits
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.11108888888888889, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=2.778222222222222, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.3336666666666663, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=3.8891111111111107, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=4.444555555555556, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.22207777777777776, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=0.5564444444444444, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.1118888888888887, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=1.6673333333333331, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.2227777777777775, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.3330666666666666, SVM__C=2.778222222222222, SVM__gamma=scale;, score=nan total time=   0.0s
# ...
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l1', 'l2', 'none' (deprecated), 'elasticnet'} or None. Got 'elastic' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan -0.10549126 -0.1085937  -0.09925397 -0.10009127
#  -0.09915531 -0.09891366 -0.09916867 -0.09813714 -0.09925537 -0.09794707
#  -0.09915624 -0.09794149 -0.09923312 -0.09794149 -0.09916262 -0.09794149
#  -0.09926186 -0.09794149 -0.0992036  -0.09794149 -0.1032482  -0.1027191
#  -0.09764661 -0.09616448 -0.09713013 -0.09521589 -0.09711795 -0.0946414
#  -0.09714251 -0.09445525 -0.09699935 -0.09445014 -0.09703648 -0.09445014
#  -0.09690103 -0.09445014 -0.09695522 -0.09445014 -0.09683741 -0.09445014
#  -0.10294099 -0.10178128 -0.09776769 -0.09580134 -0.09718725 -0.09493695
#  -0.09713136 -0.09446532 -0.09716883 -0.09431493 -0.09705382 -0.09430996
#  -0.09712244 -0.09430996 -0.09701389 -0.09430996 -0.09709603 -0.09430996
#  -0.09700773 -0.09430996 -0.10171638 -0.10022531 -0.09730553 -0.09509068
#  -0.09663486 -0.09428532 -0.09658576 -0.09390089 -0.09665179 -0.09377411
#  -0.09657691 -0.09376989 -0.09668553 -0.09376989 -0.09661178 -0.09376989
#  -0.09672263 -0.09376989 -0.09666374 -0.09376989 -0.10075757 -0.09966271
#  -0.09755505 -0.0955194  -0.09674949 -0.09466517 -0.09671628 -0.09427435
#  -0.09678311 -0.09414985 -0.09672585 -0.09414653 -0.09685304 -0.09414653
#  -0.09679147 -0.09414653 -0.09690269 -0.09414653 -0.09684742 -0.09414653
#  -0.09930346 -0.09894531 -0.09755533 -0.09598076 -0.09666011 -0.09504453
#  -0.09664745 -0.09462461 -0.09671405 -0.09450316 -0.0966839  -0.09450065
#  -0.09684031 -0.09450065 -0.09680398 -0.09450065 -0.09692351 -0.09450065
#  -0.09687936 -0.09450065 -0.09767774 -0.09788442 -0.09715821 -0.09621167
#  -0.0962255  -0.09519624 -0.09623068 -0.09475302 -0.09630076 -0.0946422
#  -0.09630559 -0.09464038 -0.09649919 -0.09464038 -0.09650204 -0.09464038
#  -0.09664321 -0.09464038 -0.09662261 -0.09464038 -0.09615046 -0.09675249
#  -0.09660875 -0.09631501 -0.09567365 -0.09523066 -0.09568865 -0.0947735
#  -0.09576604 -0.09467826 -0.09580687 -0.09467706 -0.09603753 -0.09467706
#  -0.09608546 -0.09467706 -0.09625865 -0.09467706 -0.0962717  -0.09467706
#  -0.09489493 -0.09579797 -0.09612855 -0.09642503 -0.09520973 -0.09528479
#  -0.09522715 -0.0948222  -0.09531485 -0.09474385 -0.09539038 -0.09474319
#  -0.09565543 -0.09474319 -0.09574821 -0.09474319 -0.09595772 -0.09474319
#  -0.09600936 -0.09474319 -0.09400471 -0.09514875 -0.0958341  -0.09663159
#  -0.09493949 -0.09544794 -0.09495496 -0.09498588 -0.09505456 -0.09492342
#  -0.09516195 -0.09492321 -0.09545771 -0.09492321 -0.09559134 -0.09492321
#  -0.09583633 -0.09492321 -0.09592664 -0.09492321         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  -0.10616642 -0.10900004 -0.09946108 -0.10027425 -0.09941736 -0.09910176
#  -0.09944944 -0.09832949 -0.09954563 -0.09814109 -0.09945622 -0.09813523
#  -0.09954407 -0.09813523 -0.09948392 -0.09813523 -0.09959797 -0.09813523
#  -0.09955128 -0.09813523 -0.10386225 -0.10299268 -0.09780009 -0.09624513
#  -0.09733389 -0.09531727 -0.0973367  -0.09475604 -0.09737022 -0.09457266
#  -0.09723598 -0.09456715 -0.09728344 -0.09456715 -0.09715675 -0.09456715
#  -0.09722414 -0.09456715 -0.09711617 -0.09456715 -0.10352323 -0.1020142
#  -0.0978958  -0.09585563 -0.09736134 -0.09501157 -0.09731857 -0.09455274
#  -0.09736509 -0.09440514 -0.09725891 -0.09439978 -0.09733791 -0.09439978
#  -0.09723813 -0.09439978 -0.09733344 -0.09439978 -0.097255   -0.09439978
#  -0.10221551 -0.10040125 -0.09741048 -0.09512768 -0.09677336 -0.09434057
#  -0.09673563 -0.09396716 -0.09680935 -0.09384266 -0.0967414  -0.09383809
#  -0.09685813 -0.09383809 -0.09679086 -0.09383809 -0.09691168 -0.09383809
#  -0.09685963 -0.09383809 -0.10107331 -0.09978855 -0.09764011 -0.09554968
#  -0.09685402 -0.09471016 -0.09683151 -0.09432751 -0.096904   -0.09420441
#  -0.09685131 -0.0942008  -0.09698399 -0.0942008  -0.09692616 -0.0942008
#  -0.09704361 -0.0942008  -0.09699186 -0.0942008  -0.09949303 -0.09904725
#  -0.09763037 -0.09601356 -0.09674672 -0.09508984 -0.09674454 -0.0946764
#  -0.09681584 -0.09455586 -0.09678945 -0.09455308 -0.09695064 -0.09455308
#  -0.09691717 -0.09455308 -0.0970413  -0.09455308 -0.0969994  -0.09455308
#  -0.09781796 -0.0979747  -0.09723087 -0.09625243 -0.09630574 -0.09524836
#  -0.09632107 -0.09481075 -0.09639543 -0.09470062 -0.09640377 -0.09469855
#  -0.09660198 -0.09469855 -0.09660746 -0.09469855 -0.09675251 -0.09469855
#  -0.09673367 -0.09469855 -0.09626332 -0.09683391 -0.09668237 -0.09636435
#  -0.09575296 -0.09529048 -0.09577756 -0.09483833 -0.09585908 -0.0947437
#  -0.09590336 -0.09474226 -0.09613857 -0.09474226 -0.09618914 -0.09474226
#  -0.09636598 -0.09474226 -0.09638072 -0.09474226 -0.09498746 -0.09587103
#  -0.0962036  -0.09648143 -0.09528962 -0.09535094 -0.09531597 -0.0948929
#  -0.0954078  -0.0948151  -0.0954869  -0.09481421 -0.09575657 -0.09481421
#  -0.09585213 -0.09481421 -0.09606532 -0.09481421 -0.0961188  -0.09481421
#  -0.0940831  -0.0952151  -0.09591009 -0.09669328 -0.09501994 -0.09551873
#  -0.09504371 -0.09506088 -0.09514752 -0.09499895 -0.09525871 -0.09499851
#  -0.09555921 -0.09499851 -0.09569582 -0.09499851 -0.09594462 -0.09499851
#  -0.09603702 -0.09499851]
#   warnings.warn(

# %%
print(gcv.best_params_)
# Out:
# {'LR__penalty': 'l2', 'NB__var_smoothing': 0.3330666666666666, 'SVM__C': 2.778222222222222, 'SVM__gamma': 'auto'}

# %%
bm = gcv.best_estimator_
